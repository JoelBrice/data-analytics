# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from bokeh.plotting import figure, show

# %%
data = pd.read_csv("tips.csv")

# %%
display(data.head(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
 # Plot a scatter plot day vs tip
plt.scatter(data["day"], data["tip"], c = data["size"],s = data["total_bill"], )

#Add title to the plot
plt.title("Scatter plot")

plt.xlabel("Day")
plt.ylabel("Tip")
plt.show()

# %%
#Using a linear chart, let's display the tip vs size
plt.plot(data["tip"])
plt.plot(data["size"])

# %%
#Display using histogram with Seaborn library
sns.histplot(x='total_bill', data=data, kde=True, hue='sex')
  
plt.show()

# %%
#Use regression plot
sns.regplot(x="total_bill", y="tip", data=data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# create a new plot
p = figure(title="Plot with Bokeh")
line = p.line(data['total_bill'], data['tip'], legend_label="Temp.", line_color="blue", line_width=2)

circle = p.circle (
    data['total_bill'],
    data['tip'],
    legend_label="Objects",
    fill_color="red",
    fill_alpha=0.5,
    line_color="blue",
    size=10,
)

# %%
# display legend in top left corner (default is top right corner)
p.legend.location = "top_left"

# add a title to your legend
p.legend.title = "Tips line chart"

# change appearance of legend text
p.legend.label_text_font = "times"
p.legend.label_text_font_style = "italic"
p.legend.label_text_color = "navy"

# change border and background of legend
p.legend.border_line_width = 3
p.legend.border_line_color = "navy"
p.legend.border_line_alpha = 0.8
p.legend.background_fill_color = "navy"
p.legend.background_fill_alpha = 0.2

# show the results
show(p)
